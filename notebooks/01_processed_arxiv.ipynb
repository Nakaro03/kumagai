# %%
import sys
import os
import importlib

# srcフォルダのパス設定
sys.path.append(os.path.abspath(".."))

# configを書き換えたので、念のためリロードするおまじない
import src.config
import src.data_loader
importlib.reload(src.config)
importlib.reload(src.data_loader)

from src.data_loader import fetch_arxiv_data
from src.config import START_YEAR, END_YEAR

# config.py で設定した 2020, 2022 が読み込まれます
print(f"設定: {START_YEAR}年 〜 {END_YEAR}年")

# 実行
fetch_arxiv_data(start_year=START_YEAR, end_year=END_YEAR)
# Out:
# 設定: 2020年 〜 2022年
# 【開始】2020年 ~ 2022年のデータを取得します
# 保存先: ../data/raw/arxiv_cs_raw_2020-2022.csv
# --> 2020年 検索中 (試行 1/10)...  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#   -> 3617件 (残り全て) 保存完了
# OK: 2020年の処理完了 (合計 3617件)
# --> 2021年 検索中 (試行 1/10)...  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
#  -> 100件 保存完了
# ...
