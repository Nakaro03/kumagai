# %%
import pandas as pd

df = pd.read_csv('/home/nakamuraroi/kumagai/data/raw/arxiv_cs_raw_2020-2026.csv')
df
# Out:
#                                                    title  \
# 0        Bosonic Random Walk Networks for Graph Learning
# 1      Integrated Generalized Zero-Shot Learning for ...
# 2      Controlled Analyses of Social Biases in Wikipe...
# 3      A Multi-modal Deep Learning Model for Video Th...
# 4      Explicit regularization and implicit bias in d...
# ...                                                  ...
# 56502  UETQuintet at BioCreative IX -- MedHopQA: Enha...
# 56503  LLMs Can't Play Hangman: On the Necessity of a...
# 56504  Categorize Early, Integrate Late: Divergent Pr...
# 56505  Generalization Bounds for Transformer Channel ...
# 56506  A Robust Certified Machine Unlearning Method U...
#
#                                              description  \
# 0      The development of Graph Neural Networks (GNNs...
# 1      Embedding learning (EL) and feature synthesizi...
# 2      Social biases on Wikipedia, a widely-read glob...
# ...

# %%
# 1. 重複している行数をカウント
duplicate_count = df.duplicated().sum()
print(f"データ総数: {len(df)}")
print(f"完全に重複している行数: {duplicate_count}")
# Out:
# データ総数: 56507
# 完全に重複している行数: 27803
