# %% [markdown]
# # クイックテスト - NeuralODE+VGAE分析
#
# このノートブックは、重いライブラリを段階的にインポートして、
# 分析の各段階をテストするための軽量版です。

# %%
# ステップ1: 基本ライブラリのテスト
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import os
import time

warnings.filterwarnings('ignore')

print("✅ 基本ライブラリのインポート完了")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")

# %%
# ステップ2: データ読み込みテスト
start_time = time.time()

data_path = '../processed_data/kumagai_patentdata.csv'
if os.path.exists(data_path):
    df = pd.read_csv(data_path)
    print(f"✅ データ読み込み完了: {df.shape}")
    print(f"列名: {list(df.columns)[:10]}...")
    print(f"読み込み時間: {time.time() - start_time:.2f}秒")
else:
    print(f"❌ データファイルが見つかりません: {data_path}")
    print("利用可能なファイル:")
    for file in os.listdir('../processed_data/'):
        print(f"  - {file}")
